# %%
import requests
import datetime
import time
import re
group_id = -35528695
#ID сообществ нужно писать с минусом, профиля - без
count = 100 #количество постов, получаемых за 1 запрос
offset = 0 #начальное смещение

#Узнаем сколько постов в сообществе
Token = '7bcbe786dc30553c097010cd323a82438b03a9570a1713e4386e254fac5cc292d2e110a74936f5fc2a1c8'
r = requests.get('https://api.vk.com/method/wall.get',params={'owner_id':group_id,'count':0, 'access_token':Token})
response = r.json()
post_count = r.json()['response'][0] #количество постов в группе или профиле
print('Количество постов в сообществе:',post_count)

print('Дата публикации',',','Ссылка',',','Количество лайков',',','Количество репостов','паблик постер', 'паблик источник', 'ссылка на пост')

while offset < post_count:
    r = requests.get('https://api.vk.com/method/wall.get',params={'owner_id':group_id,'count':count, 'offset':offset, 'access_token':Token})
    response = r.json()
    #запускаем цикл для обработки ответа
    for i in range(1,101):
        post_date_unix = response['response'][i]['date']
        post_date =  datetime.datetime.fromtimestamp( #функция преобразования
                int(response['response'][i]['date'])
                ).strftime('%Y-%m-%d') #фортма преобразования Год-Месяц Час-Минута-Секунда   
        post_date_h =  datetime.datetime.fromtimestamp( #функция преобразования
                int(response['response'][i]['date'])
                ).strftime('%H:%M:%S') #фортма преобразования Год-Месяц Час-Минута-Секунда
        likes_count = r.json()['response'][i]['likes']['count']
        repost_count = r.json()['response'][i]['reposts']['count']
        from_id = re.search(r'(\d+)', str(response['response'][i]['from_id'])).group() #эта загогулина нужна для паблика источника
        to_id = r.json()['response'][i]['to_id'] # эта загогулина нужна для построения ссылки
        uid = r.json()['response'][i]['id'] # эта загогулина нужна для айди поста 
        if 'copy_owner_id' in response['response'][i]:
            copy_owner_id = re.search(r'(\d+)', str(response['response'][i]['copy_owner_id'])).group()
        else:
            copy_owner_id = re.search(r'(\d+)', str(response['response'][i]['to_id'])).group()
        print(post_date, post_date_h, likes_count, repost_count,'vk.com/public' +str(from_id), 'vk.com/public'+str(copy_owner_id), 'https://vk.com/wall'+str(to_id)+'_'+str(uid))
    offset = offset + 100
    time.sleep(.33)
    if  post_date_unix > 1498953600: # 1 марта = 1488326400
        continue
    else:
        break
# Out:
# Количество постов в сообществе: 1092
# Дата публикации , Ссылка , Количество лайков , Количество репостов паблик постер паблик источник ссылка на пост
# 2017-10-02 15:00:12 4 0 vk.com/public35528695 vk.com/public35528695 https://vk.com/wall-35528695_1730
# 2017-10-02 11:16:29 4 2 vk.com/public35528695 vk.com/public35528695 https://vk.com/wall-35528695_1727
# 2017-09-30 10:00:12 6 1 vk.com/public35528695 vk.com/public35528695 https://vk.com/wall-35528695_1726
# 2017-09-29 15:36:15 2 0 vk.com/public35528695 vk.com/public34312478 https://vk.com/wall-35528695_1724
# 2017-09-29 14:00:11 7 0 vk.com/public35528695 vk.com/public35528695 https://vk.com/wall-35528695_1723
# 2017-09-28 10:45:29 5 4 vk.com/public35528695 vk.com/public35528695 https://vk.com/wall-35528695_1721
# 2017-09-28 09:10:46 3 0 vk.com/public35528695 vk.com/public35528695 https://vk.com/wall-35528695_1719
# 2017-09-27 10:47:17 4 2 vk.com/public35528695 vk.com/public34777837 https://vk.com/wall-35528695_1718
# ...

# %%
import requests
import datetime
import time
import re

group_id = -36941146
#ID сообществ нужно писать с минусом, профиля - без
count = 100 #количество постов, получаемых за 1 запрос
offset = 0 #начальное смещение

#Узнаем сколько постов в сообществе
Token = '7bcbe786dc30553c097010cd323a82438b03a9570a1713e4386e254fac5cc292d2e110a74936f5fc2a1c8'
r = requests.get('https://api.vk.com/method/wall.get',params={'owner_id':group_id,'count':0, 'access_token':Token})
response = r.json()
post_count = r.json()['response'][0] #количество постов в группе или профиле
print('Количество постов в сообществе:',post_count)

print('Дата публикации',',','Ссылка',',','Количество лайков',',','Количество репостов','паблик постер', 'паблик источник', 'ссылка на пост')

while offset < post_count:
    r = requests.get('https://api.vk.com/method/wall.get',params={'owner_id':group_id,'count':count, 'offset':offset, 'access_token':Token})
    response = r.json()
    #запускаем цикл для обработки ответа
    for i in range(1,101):
        post_date_unix = response['response'][i]['date']
        post_date =  datetime.datetime.fromtimestamp( #функция преобразования
                int(response['response'][i]['date'])
                ).strftime('%Y-%m-%d') #фортма преобразования Год-Месяц Час-Минута-Секунда   
        post_date_h =  datetime.datetime.fromtimestamp( #функция преобразования
                int(response['response'][i]['date'])
                ).strftime('%H:%M:%S') #фортма преобразования Год-Месяц Час-Минута-Секунда
        likes_count = r.json()['response'][i]['likes']['count']
        repost_count = r.json()['response'][i]['reposts']['count']
        from_id = re.search(r'(\d+)', str(response['response'][i]['from_id'])).group() #эта загогулина нужна для паблика источника
        to_id = r.json()['response'][i]['to_id'] # эта загогулина нужна для построения ссылки
        uid = r.json()['response'][i]['id'] # эта загогулина нужна для айди поста 
        if 'copy_owner_id' in response['response'][i]:
            copy_owner_id = re.search(r'(\d+)', str(response['response'][i]['copy_owner_id'])).group()
        else:
            copy_owner_id = re.search(r'(\d+)', str(response['response'][i]['to_id'])).group()
        print(post_date, post_date_h, likes_count, repost_count,'vk.com/public' +str(from_id), 'vk.com/public'+str(copy_owner_id), 'https://vk.com/wall'+str(to_id)+'_'+str(uid))
    offset = offset + 100
    time.sleep(.33)
    if  post_date_unix > 1488326400:
        continue
    else:
        break
# Out:
# Количество постов в сообществе: 9670
# Дата публикации , Ссылка , Количество лайков , Количество репостов паблик постер паблик источник ссылка на пост
# 2017-09-20 15:47:35 98 19 vk.com/public36941146 vk.com/public36941146 https://vk.com/wall-36941146_63851
# 2017-09-26 17:07:53 9 0 vk.com/public36941146 vk.com/public36941146 https://vk.com/wall-36941146_63963
# 2017-09-26 16:35:40 12 0 vk.com/public36941146 vk.com/public36941146 https://vk.com/wall-36941146_63960
# 2017-09-26 09:57:52 10 0 vk.com/public36941146 vk.com/public36941146 https://vk.com/wall-36941146_63957
# 2017-09-26 08:39:45 7 0 vk.com/public36941146 vk.com/public36941146 https://vk.com/wall-36941146_63951
# 2017-09-26 08:09:29 17 0 vk.com/public36941146 vk.com/public36941146 https://vk.com/wall-36941146_63949
# 2017-09-26 08:05:27 8 1 vk.com/public36941146 vk.com/public36941146 https://vk.com/wall-36941146_63948
# 2017-09-26 08:01:49 10 1 vk.com/public36941146 vk.com/public54984104 https://vk.com/wall-36941146_63947
# ...

# %%
import requests
import datetime
import time
import re
group_id = -29062072 #ID сообществ нужно писать с минусом, профиля - без


#Узнаем сколько постов в сообществе
Token = '7bcbe786dc30553c097010cd323a82438b03a9570a1713e4386e254fac5cc292d2e110a74936f5fc2a1c8'
with open ('C:/Users/alnag/Documents/numbersid1.txt', "r") as f:
    lines = f.readlines()
a = [l.strip() for l in lines]
#print('Count', 'first post date', 'Today date', 'Days gone', 'average')
r = requests.get('https://api.vk.com/method/wall.get',params={'owner_id':group_id,'count':0, 'access_token':Token})
response = r.json()
post_count = r.json()['response'][0]
offset = int(post_count) - 1
r = requests.get('https://api.vk.com/method/wall.get',params={'owner_id':group_id,'count':1, 'offset':offset, 'access_token':Token})
response = r.json()
post_date =  datetime.datetime.fromtimestamp( #функция преобразования
            int(response['response'][1]['date'])
            ).strftime('%Y-%m-%d') #фортма преобразования Год-Месяц Час-Минута-Секунда    
now = datetime.datetime.now().strftime('%Y-%m-%d')
a = post_date.split('-')
b = now.split('-')
aa = datetime.date(int(a[0]),int(a[1]),int(a[2]))
bb = datetime.date(int(b[0]),int(b[1]),int(b[2]))
avr = str((bb - aa)). split(' ')
cc = round((int(offset)/int(avr[0]))*7)

#print(post_count, post_date, now, cc, avr)
print(cc)
# Out:
# 43

# %%
import requests, time
Token = 'dc266595e988265470963b6abcf385d0ebbe32fa45be4d9b0d2b0537d30bdafcac89ddec1584aab75a83d'
group_id = -86559535 
count = 100
offset = 0
r = requests.get('https://api.vk.com/method/wall.get',params={'owner_id':group_id,'count':count, 'access_token':Token, 'offset':offset+400})
response = r.json()
offset = offset+100
time.sleep(0.33)
# print(response)
for i in range(1, count+1):
    try:
        if 'poll' in response['response'][i]['attachment']: 
            poll_id = response['response'][i]['attachment']['poll']['poll_id']
            u = requests.get('https://api.vk.com/method/polls.getById',params={'owner_id':group_id,'poll_id':poll_id, 'access_token':Token})
            print(u.json())

        else:
            print(None)
    except Exception:
        print('Fuck you')
# Out:
# None
# None
# None
# None
# None
# None
# None
# Fuck you
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# Fuck you
# Fuck you
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# Fuck you
# None
# None
# None
# None
# None
# None
# None
# None
# Fuck you
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# Fuck you
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
